# %%
import pandas as pd

# %%
notaSemillero=pd.DataFrame({'NOMBRES':['Pedro', 'Darden', 'LeidyDarden'], 
                            'SEMESTRE' : [10, 7 ,8] ,
          
                            })
notaSemillero['Nota1']=3
notaSemillero
notaSemillero['Nota2']=[3.1, 4.2, 3.3]
notaSemillero
#print(notaSemillero)
# Out:
#        NOMBRES  SEMESTRE  Nota1  Nota2
# 0        Pedro        10      3    3.1
# 1       Darden         7      3    4.2
# 2  LeidyDarden         8      3    3.3

# %%
notaSemillero['Nota2']=[3.1, 4.2, 3.3]
notaSemillero
# Out:
#        NOMBRES  SEMESTRE  Nota1  Nota2
# 0        Pedro        10      3    3.1
# 1       Darden         7      3    4.2
# 2  LeidyDarden         8      3    3.3

# %%
notaSemillero.insert(1, 'CIUDAdd',['Manizales', 'Pereira', 'Aguadas'] )
notaSemillero
# Out:
#        NOMBRES    CIUDAdd  SEMESTRE  Nota1  Nota2
# 0        Pedro  Manizales        10      3    3.1
# 1       Darden    Pereira         7      3    4.2
# 2  LeidyDarden    Aguadas         8      3    3.3

# %%
notaSemillero.assign(DEPARTAMENTO=['Caldas', 'Risaralda', 'Caldas'] )
notaSemillero
# Out:
#        NOMBRES    CIUDAdd  SEMESTRE  Nota1  Nota2
# 0        Pedro  Manizales        10      3    3.1
# 1       Darden    Pereira         7      3    4.2
# 2  LeidyDarden    Aguadas         8      3    3.3
